# %%
from pymongo import MongoClient
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
import numpy as np
import logging
from time import time

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# Connect to MongoDB cloud database
mongo_uri = "mongodb+srv://aparnabharathi:aparnabharathi@inventorrecommendations.mbvnl.mongodb.net/"
client = MongoClient(mongo_uri)
db = client['inv']  # Replace with your database name
users_collection = db['inventor']

# Fetch user data from MongoDB
logging.info("Fetching user data from MongoDB...")
start_time = time()
users = list(users_collection.find({}))
num_users = len(users)
logging.info(f"Fetched {num_users} records from the database in {time() - start_time:.2f} seconds.")

# Simulated content-based vectors (replace with real content features if available)
logging.info("Generating random content vectors for content-based similarity...")
content_vectors = np.random.rand(num_users, 5).astype('float32')  # Use float32 for reduced memory

# Collaborative similarity: Sparse matrix representation
logging.info("Building collaborative similarity sparse matrix...")
row, col, data = [], [], []

for i, user in enumerate(users):
    user_followers = {f.get('email') for f in user.get('followers', []) if isinstance(f, dict)}
    user_following = {f.get('email') for f in user.get('following', []) if isinstance(f, dict)}

    for j, other_user in enumerate(users):
        if i != j:
            other_followers = {f.get('email') for f in other_user.get('followers', []) if isinstance(f, dict)}
            other_following = {f.get('email') for f in other_user.get('following', []) if isinstance(f, dict)}

            # Compute shared followers and following
            shared_followers = user_followers.intersection(other_followers)
            shared_following = user_following.intersection(other_following)

            # Add similarity score to sparse matrix if non-zero
            similarity = len(shared_followers) + len(shared_following)
            if similarity > 0:
                row.append(i)
                col.append(j)
                data.append(similarity)

    if i % 1000 == 0:  # Log progress every 1000 users
        logging.info(f"Processed {i}/{num_users} users for collaborative similarity.")

# Create sparse collaborative matrix
collab_matrix = csr_matrix((data, (row, col)), shape=(num_users, num_users), dtype='float32')

# Normalize collaborative similarity
logging.info("Normalizing collaborative similarity sparse matrix...")
if collab_matrix.max() > 0:
    collab_matrix = collab_matrix / collab_matrix.max()

# Content-based similarity using NearestNeighbors
logging.info("Calculating content-based similarity using Nearest Neighbors...")
n_neighbors = 10  # Number of recommendations per user
nbrs = NearestNeighbors(n_neighbors=n_neighbors + 1, metric='cosine', algorithm='brute')
nbrs.fit(content_vectors)
distances, indices = nbrs.kneighbors(content_vectors)

# Generate recommendations in batches
logging.info("Generating and updating hybrid recommendations in batches...")
alpha, beta = 0.5, 0.5  # Weights for hybridization

for user_index, user in enumerate(users):
    # Hybrid similarity for the current user
    hybrid_scores = collab_matrix[user_index].toarray().flatten() * alpha

    for j, neighbor_idx in enumerate(indices[user_index][1:]):  # Exclude self
        hybrid_scores[neighbor_idx] += beta * (1 - distances[user_index][j + 1])  # Invert distance for similarity

    # Get top N recommendations
    top_indices = hybrid_scores.argsort()[::-1][:n_neighbors]
    recommendations = [users[i]['name'] for i in top_indices if i < len(users)]

    # Update recommendations in MongoDB
    users_collection.update_one(
        {'_id': user['_id']},  # Match user by MongoDB's unique ID
        {'$set': {'recommendations': recommendations}}  # Update recommendations field
    )

    if user_index % 1000 == 0:  # Log progress every 1000 users
        logging.info(f"Updated recommendations for {user_index}/{num_users} users.")

logging.info("Hybrid recommendations have been successfully updated in the MongoDB database.")
# Out:
# 2024-12-14 00:48:23,482 - INFO - Fetching user data from MongoDB...
# 2024-12-14 00:48:28,142 - INFO - Fetched 32204 records from the database in 4.64 seconds.
# 2024-12-14 00:48:28,142 - INFO - Generating random content vectors for content-based similarity...
# 2024-12-14 00:48:28,163 - INFO - Building collaborative similarity sparse matrix...
# 2024-12-14 00:48:28,237 - INFO - Processed 0/32204 users for collaborative similarity.
# 2024-12-14 00:49:11,705 - INFO - Processed 1000/32204 users for collaborative similarity.
# 2024-12-14 00:50:01,598 - INFO - Processed 2000/32204 users for collaborative similarity.
# 2024-12-14 00:50:45,071 - INFO - Processed 3000/32204 users for collaborative similarity.
# 2024-12-14 00:51:27,765 - INFO - Processed 4000/32204 users for collaborative similarity.
# 2024-12-14 00:52:10,318 - INFO - Processed 5000/32204 users for collaborative similarity.
# 2024-12-14 00:52:52,186 - INFO - Processed 6000/32204 users for collaborative similarity.
# 2024-12-14 00:53:33,838 - INFO - Processed 7000/32204 users for collaborative similarity.
# 2024-12-14 00:54:16,382 - INFO - Processed 8000/32204 users for collaborative similarity.
# 2024-12-14 00:54:58,118 - INFO - Processed 9000/32204 users for collaborative similarity.
# 2024-12-14 00:55:41,446 - INFO - Processed 10000/32204 users for collaborative similarity.
# 2024-12-14 00:56:23,416 - INFO - Processed 11000/32204 users for collaborative similarity.
# 2024-12-14 00:57:06,167 - INFO - Processed 12000/32204 users for collaborative similarity.
# 2024-12-14 00:57:48,082 - INFO - Processed 13000/32204 users for collaborative similarity.
# 2024-12-14 00:58:30,924 - INFO - Processed 14000/32204 users for collaborative similarity.
# 2024-12-14 00:59:13,629 - INFO - Processed 15000/32204 users for collaborative similarity.
# 2024-12-14 00:59:56,411 - INFO - Processed 16000/32204 users for collaborative similarity.
# 2024-12-14 01:00:38,505 - INFO - Processed 17000/32204 users for collaborative similarity.
# 2024-12-14 01:01:20,316 - INFO - Processed 18000/32204 users for collaborative similarity.
# 2024-12-14 01:02:02,453 - INFO - Processed 19000/32204 users for collaborative similarity.
# 2024-12-14 01:02:45,024 - INFO - Processed 20000/32204 users for collaborative similarity.
# 2024-12-14 01:03:28,235 - INFO - Processed 21000/32204 users for collaborative similarity.
# 2024-12-14 01:04:18,857 - INFO - Processed 22000/32204 users for collaborative similarity.
# 2024-12-14 01:05:02,275 - INFO - Processed 23000/32204 users for collaborative similarity.
# 2024-12-14 01:05:46,102 - INFO - Processed 24000/32204 users for collaborative similarity.
# 2024-12-14 01:06:28,104 - INFO - Processed 25000/32204 users for collaborative similarity.
# 2024-12-14 01:07:11,187 - INFO - Processed 26000/32204 users for collaborative similarity.
# 2024-12-14 01:07:53,429 - INFO - Processed 27000/32204 users for collaborative similarity.
# 2024-12-14 01:08:38,419 - INFO - Processed 28000/32204 users for collaborative similarity.
# 2024-12-14 01:09:21,315 - INFO - Processed 29000/32204 users for collaborative similarity.
# 2024-12-14 01:10:04,011 - INFO - Processed 30000/32204 users for collaborative similarity.
# 2024-12-14 01:10:46,167 - INFO - Processed 31000/32204 users for collaborative similarity.
# 2024-12-14 01:11:28,853 - INFO - Processed 32000/32204 users for collaborative similarity.
# 2024-12-14 01:11:38,351 - INFO - Normalizing collaborative similarity sparse matrix...
# 2024-12-14 01:11:38,351 - INFO - Calculating content-based similarity using Nearest Neighbors...
# 2024-12-14 01:11:56,398 - INFO - Generating and updating hybrid recommendations in batches...
# 2024-12-14 01:11:56,458 - INFO - Updated recommendations for 0/32204 users.
# 2024-12-14 01:12:37,471 - INFO - Updated recommendations for 1000/32204 users.
# 2024-12-14 01:13:19,135 - INFO - Updated recommendations for 2000/32204 users.
# 2024-12-14 01:14:00,858 - INFO - Updated recommendations for 3000/32204 users.
# 2024-12-14 01:14:42,125 - INFO - Updated recommendations for 4000/32204 users.
# 2024-12-14 01:15:26,284 - INFO - Updated recommendations for 5000/32204 users.
# 2024-12-14 01:16:10,168 - INFO - Updated recommendations for 6000/32204 users.
# 2024-12-14 01:16:52,072 - INFO - Updated recommendations for 7000/32204 users.
# 2024-12-14 01:17:33,947 - INFO - Updated recommendations for 8000/32204 users.
# 2024-12-14 01:18:15,725 - INFO - Updated recommendations for 9000/32204 users.
# 2024-12-14 01:18:57,991 - INFO - Updated recommendations for 10000/32204 users.
# 2024-12-14 01:19:39,441 - INFO - Updated recommendations for 11000/32204 users.
# 2024-12-14 01:20:22,158 - INFO - Updated recommendations for 12000/32204 users.
# 2024-12-14 01:21:06,841 - INFO - Updated recommendations for 13000/32204 users.
# 2024-12-14 01:21:48,857 - INFO - Updated recommendations for 14000/32204 users.
# 2024-12-14 01:22:33,046 - INFO - Updated recommendations for 15000/32204 users.
# 2024-12-14 01:23:18,867 - INFO - Updated recommendations for 16000/32204 users.
# 2024-12-14 01:24:00,131 - INFO - Updated recommendations for 17000/32204 users.
# 2024-12-14 01:24:40,983 - INFO - Updated recommendations for 18000/32204 users.
# 2024-12-14 01:25:24,723 - INFO - Updated recommendations for 19000/32204 users.
# 2024-12-14 01:26:06,561 - INFO - Updated recommendations for 20000/32204 users.
# 2024-12-14 01:26:53,028 - INFO - Updated recommendations for 21000/32204 users.
# 2024-12-14 01:27:37,631 - INFO - Updated recommendations for 22000/32204 users.
# 2024-12-14 01:28:19,473 - INFO - Updated recommendations for 23000/32204 users.
# 2024-12-14 01:28:59,208 - INFO - Updated recommendations for 24000/32204 users.
# 2024-12-14 01:29:38,867 - INFO - Updated recommendations for 25000/32204 users.
# 2024-12-14 01:30:18,684 - INFO - Updated recommendations for 26000/32204 users.
# 2024-12-14 01:30:59,836 - INFO - Updated recommendations for 27000/32204 users.
# 2024-12-14 01:31:39,838 - INFO - Updated recommendations for 28000/32204 users.
# 2024-12-14 01:32:19,363 - INFO - Updated recommendations for 29000/32204 users.
# 2024-12-14 01:32:59,244 - INFO - Updated recommendations for 30000/32204 users.
# 2024-12-14 01:33:39,352 - INFO - Updated recommendations for 31000/32204 users.
# 2024-12-14 01:34:21,146 - INFO - Updated recommendations for 32000/32204 users.
# 2024-12-14 01:34:29,296 - INFO - Hybrid recommendations have been successfully updated in the MongoDB database.

# %%
from pymongo import MongoClient
from sklearn.neighbors import NearestNeighbors
import numpy as np

# Connect to MongoDB cloud database
mongo_uri = "mongodb+srv://aparnabharathi:aparnabharathi@inventorrecommendations.mbvnl.mongodb.net/"
client = MongoClient(mongo_uri)
db = client['inv']  # Replace with your database name
users_collection = db['inventor']

# Fetch user data from MongoDB
users = list(users_collection.find({}))  # Convert cursor to list
num_users = len(users)

# Simulated content-based vectors (replace with real content features if available)
content_vectors = np.random.rand(num_users, 5)  # Example random data

# Use Nearest Neighbors for similarity calculation
n_neighbors = 10  # Number of recommendations per user
nbrs = NearestNeighbors(n_neighbors=n_neighbors + 1, metric='cosine', algorithm='brute')  # Use 'brute' for cosine
nbrs.fit(content_vectors)

# Get indices of nearest neighbors
distances, indices = nbrs.kneighbors(content_vectors)

# Update recommendations in MongoDB
for user_index, user in enumerate(users):
    recommended_indices = indices[user_index][1:]  # Exclude self
    recommendations = [users[idx]['name'] for idx in recommended_indices if idx != user_index]
    users_collection.update_one(
        {'_id': user['_id']},
        {'$set': {'recommendations': recommendations}}
    )

print("Recommendations have been updated in the MongoDB database.")
# Out:
# Recommendations have been updated in the MongoDB database.
